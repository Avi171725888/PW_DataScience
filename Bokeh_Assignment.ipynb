# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# We can create a bokeh plot by importing bokeh library and creating a figure to plot the graph

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure,output_file,show
output_file("Qestion 1.html")
fig = figure(title = "Bokeh Line Graph")
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
fig.line(x, y)
show(fig)
# Out:
#   <div id="f0b8bb20-2427-41e4-89fa-7d897975cf8c" data-root-id="p1040" style="display: contents;"></div>

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# glyphs:-Display a variety of visual shapes whose attributes can be associated with data columns from ColumnDataSources.We can add them on figure object.
# Ex:-Scatter,line,Arc

# %%
from bokeh.plotting import figure,output_file,show
output_file("Qestion 1.html")
fig = figure(title = "Bokeh Line Graph")
x = [1, 2, 3, 4, 5]
y = [3, 4, 5, 6, 7]
fig.line(x, y)
show(fig)
# Out:
#   <div id="ecd44adc-d7c3-4e89-a6b5-7a235900ee61" data-root-id="p1118" style="display: contents;"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.models.annotations.legends import Legend
from bokeh.plotting import figure,output_file,show
output_file("Qestion 1.html")
fig = figure(title = "Bokeh Line Graph")
x = [1, 2, 3, 4, 5]
y = [3, 4, 5, 6, 7]
fig.xaxis.axis_label="This is x axis"
fig.yaxis.axis_label="This is x axis"
fig.line(x, y,legend_label="line")
show(fig)
# Out:
#   <div id="ecb8ba22-ae0e-497a-a31d-63f994be3f06" data-root-id="p1337" style="display: contents;"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# The Bokeh server is a component of Bokeh that allows you to build interactive web applications that are connected to Python code running on a server.

# %% [markdown]
# You can directly interact with the Bokeh server via a client API, which you can use to make modifications to Bokeh documents in existing sessions on a Bokeh server.
#
# This can be useful, for example, to make user-specific customizations to a Bokeh app that is embedded by another web framework, such as Flask or Django. In the following example, a Flask endpoint embeds a “sliders” app already running on the server but changes the plot title before passing the output to the user.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# With Bokeh you can build stand-alone and server-based data visualizations. The stand-alone visualizations are generated once in your Python environment and then saved to a file (or just delivered to a browser). The plots are then drawn and made interactive using BokehJS, the client-side JavaScript library, that needs to be included in your page.
#
# If you want your visualizations to be based on large datasets, use streaming data, auto-downsamling for efficiency, and other goodness, you can use the Bokeh Server component.
#
# For this tutorial I assume that you…
#
# Don’t want to run another server component (i.e. Bokeh Server)
# Have an existing Flask app that should do the processing / data delivery
# Nevertheless want to refresh your visualizations in short intervals using AJAX requests
